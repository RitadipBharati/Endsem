# %%
import import_ipynb
from MyLibrary import *
import math
# Out:
# importing Jupyter notebook from MyLibrary.ipynb

# %%
L=10
a=0.01
T_a=20
def Func5(y,u,x):
    return(-a*(T_a-y))

# %%
X4,Y4=Shooting_RK4(Func5,40,0,200,10,0,10,0.005,0.001,c1=-4,c2=5)
plt.plot(X4,Y4,"-.")
#Ritadip 1911129plt.scatter(A,B)
plt.xlabel("x")
plt.ylabel("T")
plt.grid()
plt.show()

# %%
plt.plot(X4,Y4,"-.")
plt.xlim(4.42,4.44)
plt.ylim(99.75,100.8)
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
print("the T is 100 C at x=4.4250")
# Out:
# the T is 100 C at x=4.4250
